# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress
import scipy.stats as stats
import numpy as np

# %%
Zillow_Ohio_csv = "../Resources/newZillowOH_data.csv"
# crime2017_csv = "Resources/OhioCrime2017_NoNan.csv"
# crime2016_csv = "Resources/OhioCrime2016_NoNan.csv"
Ohio_Crime_csv = "../Resources/CrimeData_merged.csv"
crime_by_citysize_csv= "../Resources/CrimeDatabyCitySize_clean.csv"
houseprice_by_citysize_csv = "../Resources/HousePriceCitySize_clean.csv"
crimeandprice_csv= "../Resources/CrimeandPricebySize.csv"

# %%
zillow_df = pd.read_csv(Zillow_Ohio_csv)
zillow_df = zillow_df.fillna(0)
ohiocrime_df = pd.read_csv(Ohio_Crime_csv)
crime_bysizedf = pd.read_csv(crime_by_citysize_csv)
houseprice_bysizedf = pd.read_csv(houseprice_by_citysize_csv) 
crimeandprice_df=pd.read_csv(crimeandprice_csv)
# #crime2017_df.dropna(how='all')

# crime2017_df = crime2017_df.fillna(0)

# crime2017_df['County'] = crime2017_df['County'].str.upper()
# crime2017_df.head()
# #crime2017_df.columns

# crime2016_df = pd.read_csv(crime2016_csv)
# #crime2017_df.dropna(how='all')

# crime2016_df = crime2016_df.fillna(0)

# crime2016_df['County'] = crime2016_df['County'].str.upper()
# crime2016_df.head()

# %%
#zillow_df['CountyName'] = zillow_df['CountyName'].str.upper()
#zillow_df.head()
zillow_df = zillow_df.rename(columns={"RegionName": "City", "2017": "2017 Median Price", "2016":"2016 Median Price",
                                     "2015": "2015 Median Price", "2014": "2014 Median Price", "2013":"2013 Median Price",
                                     "2012":"2012 Median Price"})
zillow_df.columns
# Out:
# Index(['RegionID', 'City', 'StateName', 'SizeRank', '2012 Median Price',
#        '2013 Median Price', '2014 Median Price', '2015 Median Price',
#        '2016 Median Price', '2017 Median Price'],
#       dtype='object')

# %%
# merge_Crime_df = pd.merge(crime2016_df, crime2017_df, left_on="City", right_on="City")
# merge_Crime_df.head()
# merge_Crime_df.to_csv("merge_Crime_df1.csv")

# merge_Crime_df.columns

# %%
merge_Zillow_Crime_df = pd.merge(ohiocrime_df, zillow_df, on = "City")
#merge_Zillow_Crime_df = merge_Zillow_Crime_df.fillna(0)
merge_Zillow_Crime_df.to_csv("MergeDataMaria.csv")
merge_Zillow_Crime_df.head()

#merge_Zillow_Crime_df.columns

merge_Zillow_Crime_df=merge_Zillow_Crime_df.sort_values("2017 Population", ascending=False)
merge_ZillowCrime_df = merge_Zillow_Crime_df.drop_duplicates()
merge_ZillowCrime_df
# Out:
#      Unnamed: 0  Unnamed: 0_x          County_x               City  \
# 45          112           197   Franklin County           Columbus
# 13           65           117   Cuyahoga County          Cleveland
# 59          147           257   Hamilton County         Cincinnati
# 77          196           381      Lucas County             Toledo
# 113         306           583     Summit County              Akron
# 25           82           144   Cuyahoga County              Parma
# 4           109           194     Butler County          Fairfield
# 108         291           566      Stark County             Canton
# 81          206           401   Mahoning County         Youngstown
# 74          191           375     Lorain County             Lorain
# 5            31            53     Butler County           Hamilton
# 8            35            59     Butler County       West Chester
# 9            38            71      Clark County        Springfield
# 36              6950                   4            0          1
# 123             6844                   1            0          0
# 100             5928                  21            0         12
# 38              5778                   2            0          1
# 110             5428                   2            0          1
# 53              5199                  10            0          1
# 70              5025                   2            0          1
# 37              4603                   1            0          0
# 31              4534                   3            0          1
# 118             3669                   5            0          0
# 33              2510                   1            0          1
# 7               2181                   2            0          0
# 10              2070                   2            0          1
# 98              1273                   0            0          0
# 0               1199                   7            0          3
# 90               995                   2            0          0
# 42               936                   3            0          1
# 12               823                   0            0          0
# 57               471                   0            0          0
# 105              287                   0            0          0
# 52               168                   0            0          0
# 41                76                   0            0          0
# 82                11                   0            0          0
# 55                 2                   0            0          0
#
#      2017 Robbery  2017 Aggravated Assault  ...  2013 Aggravated Assault  \
# 45           1963                     1454  ...                   1213.0
# 13           2697                     2698  ...                   1792.0
# 59           1196                     1275  ...                      NaN
# 77            780                     1834  ...                   1783.0
# 113           395                      731  ...                      NaN
# 25             37                       65  ...                     32.0
# 4               6                       17  ...                     70.0
# 108           188                      535  ...                    233.0
# 81            151                      241  ...                    317.0
# 74             87                      254  ...                    106.0
# 5             111                      123  ...                    131.0
# 8              15                       28  ...                     16.0
# 9             177                      159  ...                    167.0
# 58             26                       21  ...                      NaN
# 71             64                       85  ...                      NaN
# 20             40                       26  ...                     13.0
# 115             8                       21  ...                      NaN
# 18            118                      155  ...                     57.0
# 54              9                       16  ...                      NaN
# 17             79                       34  ...                     44.0
# 3              12                       66  ...                     70.0
# 65             24                       76  ...                     44.0
# 47             24                        5  ...                      5.0
# 39             33                       70  ...                     58.0
# 80             31                       16  ...                      2.0
# 32              8                        8  ...                      1.0
# 91             20                       40  ...                      NaN
# 48              2                        9  ...                      9.0
# 46              5                        6  ...                      7.0
# 49              6                        3  ...                      2.0
# ..            ...                      ...  ...                      ...
# 44             12                        7  ...                     11.0
# 76              2                        0  ...                      1.0
# 24              1                        1  ...                      1.0
# 34              3                        3  ...                      2.0
# 2               1                        2  ...                      NaN
# 83              0                        2  ...                      NaN
# 36              1                        2  ...                      1.0
# 123             1                        0  ...                      NaN
# 100             3                        6  ...                      8.0
# 38              0                        1  ...                      NaN
# 110             0                        1  ...                      1.0
# 53              0                        9  ...                      6.0
# 70              0                        1  ...                      1.0
# 37              0                        1  ...                      NaN
# 31              1                        1  ...                      1.0
# 118             1                        4  ...                      NaN
# 33              0                        0  ...                      1.0
# 7               0                        2  ...                     35.0
# 10              0                        1  ...                      NaN
# 98              0                        0  ...                      6.0
# 0               1                        3  ...                      NaN
# 90              1                        1  ...                      NaN
# 42              1                        1  ...                     11.0
# 12              0                        0  ...                      NaN
# 57              0                        0  ...                      NaN
# 105             0                        0  ...                      NaN
# 52              0                        0  ...                      2.0
# 41              0                        0  ...                      NaN
# 82              0                        0  ...                    317.0
# 55              0                        0  ...                      NaN
#
#     RegionID  StateName  SizeRank  2012 Median Price  2013 Median Price  \
# 45     10920       Ohio        15            1166700            1264400
# 13     24115       Ohio        43                  0                  0
# 59      4099       Ohio        53                  0                  0
# 77     34303       Ohio        65             466700             550500
# 18              539400             500900             598800            700300
# 54             1853200            1982500            2036200           2147700
# 17                   0             232400            1001700           1103900
# 3              1509200            1425100            1658600           1696900
# 65                   0                  0             685200           1711400
# 47             1632300            1735200            1825200           2036500
# 39             1343400            1415800            1552400           1568000
# 80                   0             537600            1061300           1072100
# 32                   0                  0                  0           2323100
# 91              996800            1073700            1183100           1272400
# 48                   0            1487000            2797800           2915100
# 46             2325800            2171700            2364500           2444200
# 49             3486600            3843600            3968900           4276500
# ..                 ...                ...                ...               ...
# 44                   0             702300            1790800           1931900
# 76                   0                  0             297400           1216300
# 24              892600            1710500            1802200           1944100
# 34             2654500            2626400            2845000           3144600
# 2               799900            1020100            1213200           1209400
# 83                   0                  0             568700           2092800
# 36                   0                  0            1500300           1933700
# 123                  0                  0             410700           1363800
# 100             652800            1520000            1604400           1526200
# 38              611400            1521400            1702500           1587100
# 110                  0                  0                  0           1160400
# 53             2436800            2261100            2433200           2563400
# 70             2499200            2910500            2375500           2588200
# 37              611400            1521400            1702500           1587100
# 31                   0                  0                  0           2323100
# 118            1880600            1885900            1849200           2040900
# 33                   0                  0                  0           2323100
# 7               893300            1918500            1990700           2107900
# 10                   0                  0                  0           1630000
# 98                   0                  0            2276600           2892600
# 0                    0                  0                  0            770200
# 90              996800            1073700            1183100           1272400
# 42                   0             702300            1790800           1931900
# 12                   0                  0                  0           1630000
# 57                   0                  0            1391000           1524200
# 105            1753500            1697000            1735400           1868000
# 52             4655800            5024200            5159200           5888300
# 41             2292400            2283300            2466800           2685000
# 82                   0             164200             261300            308200
# 55             1873600            1770600            1963900           1979400
#
# [128 rows x 51 columns]

# %%
#Tumor_Response_semUpdate = Tumor_Response_sem.pivot(index="Timepoint", columns = "Drug", values = "Tumor Volume (mm3)")

merge_Zillow_Crime_df
merge_Zillow_Crime_df["Crime Rate 2017"] = ((merge_Zillow_Crime_df["2017 Violent Crime"])/(merge_Zillow_Crime_df["2017 Population"]))*100000
merge_Zillow_Crime_df["Crime Rate 2016"] = ((merge_Zillow_Crime_df["2016 Violent Crime"])/(merge_Zillow_Crime_df["2016 Population"]))*100000
merge_Zillow_Crime_df["Crime Rate 2015"] = ((merge_Zillow_Crime_df["2015 Violent Crime"])/(merge_Zillow_Crime_df["2015 Population"]))*100000
merge_Zillow_Crime_df["Crime Rate 2014"] = ((merge_Zillow_Crime_df["2014 Violent Crime"])/(merge_Zillow_Crime_df["2014 Population"]))*100000
merge_Zillow_Crime_df["Crime Rate 2013"] = ((merge_Zillow_Crime_df["2013 Violent Crime"])/(merge_Zillow_Crime_df["2013 Population"]))*100000
#merge_Zillow_Crime_df["Crime Rate 2012"] = ((merge_Zillow_Crime_df["2012 Violent Crime"])/(merge_Zillow_Crime_df["2012 Population"]))*100000
merge_Zillow_Crime_df.reset_index().tail()
# Out:
#      index  Unnamed: 0  Unnamed: 0_x          County_x          City  \
# 123    105         274           530     Summit County     Tallmadge
# 124     52         181           359   Franklin County    New Albany
# 125     41         114           199  Fairfield County  Pickerington
# 126     82         319           605   Mahoning County    Youngstown
# 127     55         142           251            Dayton   Centerville
#
#      2017 Population  2017 Violent Crime  2017 Murder  2017 Rape  \
# 123              287                   0            0          0
# 124              168                   0            0          0
# 125               76                   0            0          0
# 126               11                   0            0          0
# 127                2                   0            0          0
#
#      2017 Robbery  ...  2013 Median Price  2014 Median Price  \
# 123             0  ...            1084600            1753500
# 124             0  ...            4896800            4655800
# 125             0  ...            2065800            2292400
# 126             0  ...                  0                  0
# 127             0  ...            1842400            1873600
#
#     2015 Median Price  2016 Median Price  2017 Median Price  Crime Rate 2017  \
# 123           1697000            1735400            1868000              0.0
# 124           5024200            5159200            5888300              0.0
# 125           2283300            2466800            2685000              0.0
# 126            164200             261300             308200              0.0
# 127           1770600            1963900            1979400              0.0
#
#      Crime Rate 2016  Crime Rate 2015  Crime Rate 2014  Crime Rate 2013
# 123       133.619938        98.665119       133.302423              NaN
# 124        48.971596        52.460392        33.141847        22.875443
# 125        80.144260              NaN              NaN              NaN
# 126       646.719651       739.972445       660.397785       813.221002
# 127        54.505052        58.611739        96.045434              NaN
#
# [5 rows x 57 columns]

# %%
Crime_PropertyValue_2017df = merge_Zillow_Crime_df[["City","2017 Median Price", "Crime Rate 2017", "2017 Population"]]
Crime_PropertyValue_2017df.head()
# citydata=Crime_PropertyValue_2017df.loc["City"]== "New Albany", ["Median Price", "2017 Population"]
# Out:
#            City  2017 Median Price  Crime Rate 2017  2017 Population
# 45     Columbus            1749600       513.411411           872205
# 13    Cleveland             625500      1556.762536           385351
# 59   Cincinnati            1436800       947.124193           299116
# 77       Toledo             861900      1020.872126           277116
# 113       Akron             692400       697.525986           197412

# %%
plt.scatter(Crime_PropertyValue_2017df["Crime Rate 2017"], Crime_PropertyValue_2017df["2017 Median Price"], color="teal", marker="o", edgecolor="black")

plt.title("2017 Housing Median Sale vs. Violent Crime Rate", fontsize=16, fontweight="bold")
plt.ylabel("Housing Median Sale")
plt.xlabel("Violent Crime Rate (per 100,000)")
plt.grid(True)
plt.show()
plt.savefig("Plots/2017 Housing Median Sale vs. Violent Crime Rate.png")

# %%
crime_rate= Crime_PropertyValue_2017df["Crime Rate 2017"]
median_housing = Crime_PropertyValue_2017df["2017 Median Price"]
population = Crime_PropertyValue_2017df["2017 Population"]
city = Crime_PropertyValue_2017df["City"]
fig, ax = plt.subplots()
fig.suptitle("2017 Ohio Crime Rate vs Median Housing Sale", fontsize=16, fontweight="bold")
plt.title("Including Population size", fontsize = 14)
# fig.suptitle("2017 Median Housing Sale vs. Violent Crime Rate", fontsize=16, fontweight="bold"
scatter = ax.scatter(crime_rate, median_housing, c=population, s=population/1000, cmap="Spectral")
                
legend1 = ax.legend(*scatter.legend_elements(),
                     loc="upper center", title="City")
ax.add_artist(legend1)
handles, labels = scatter.legend_elements(prop="sizes", alpha=0.1)
legend2 = ax.legend(handles, labels, loc="upper right", title="Population")
#plt.title("2017 Median Rental Value vs. Violent Crime Rate")
plt.ylabel("Median Housing Sale Value")
plt.xlabel("Violent Crime Rate (per 100,000)")
plt.grid(True)
plt.show()
plt.savefig("Plots/2017 Ohio Crime Rate vs Median Housing w Pop size Sale.png")

# %%
# Crime_PropertyValue_2017filtered= Crime_PropertyValue_2017df.iloc[0:4]
# plt.scatter(Crime_PropertyValue_2017df["Crime Rate 2017"], Crime_PropertyValue_2017df["2017 Median Price"], marker="o", edgecolor="black")

# plt.title("2017 Median Rental Value vs. Violent Crime Rate")
# plt.ylabel("Median Rental Value")
# plt.xlabel("Violent Crime Rate")

# plt.grid(True)
# plt.show()

# %%
Data1=pd.to_numeric(Crime_PropertyValue_2017df["Crime Rate 2017"])
Data2=pd.to_numeric(Crime_PropertyValue_2017df["2017 Median Price"])

# %%
# Set line
vc_slope, vc_int, vc_r, vc_p, vc_std_err = stats.linregress(Data1 , Data2)
fit = vc_slope * Data1 + vc_int
# Plot data
fig, ax = plt.subplots()
fig.suptitle("2017 Ohio Crime Rate vs Median Housing Sale ", fontsize=16, fontweight="bold")
#ax.set_xlim(0, 10)
#ax.set_ylim(0, 10)
plt.grid()
ax.set_xlabel("Crime Rate (Per 100,000)")
ax.plot(Data1, Data2, linewidth=0, marker='o',color="teal")
ax.plot(Data1, fit, "b--", linewidth=1)
ax.set_ylabel("Median Housing Sale")
print(vc_p)
plt.title("Pvalue ="+str(4.855181777717296e-07))
plt.show()
# Out:
# 4.855181777717296e-07

# %%
Crime_PropertyValue_2014df = merge_Zillow_Crime_df[["City","2014 Median Price", "Crime Rate 2014", "2014 Population"]]
Crime_PropertyValue_2014df.head()
# plt.scatter(Crime_PropertyValue_2016df["Crime Rate 2016"], Crime_PropertyValue_2016df["2016 Median Price"], marker="o", color="teal",edgecolor="black")

# plt.title("2016 Median Housing Sale vs. Violent Crime Rate")
# plt.ylabel("Housing Median Sale")
# plt.xlabel("Violent Crime Rate (per 100,000)")
# plt.grid(True)
# plt.show()

crime_rate= Crime_PropertyValue_2014df["Crime Rate 2014"]
median_housing = Crime_PropertyValue_2014df["2014 Median Price"]
population = Crime_PropertyValue_2014df["2014 Population"]
city = Crime_PropertyValue_2014df["City"]
fig, ax = plt.subplots()
fig.suptitle("2014 Ohio Crime Rate vs Median Housing Sale Value ", fontsize=16, fontweight="bold")
scatter = ax.scatter(crime_rate, median_housing, c=population, s=population/1000, cmap="Spectral")
                
legend1 = ax.legend(*scatter.legend_elements(),
                     loc="best", title="Population")
ax.add_artist(legend1)
handles, labels = scatter.legend_elements(prop="sizes", alpha=0.1)

plt.ylabel("Median Housing Sale Value")
plt.xlabel("Violent Crime Rate (Per 100,000)")
plt.grid(True)
plt.show()
plt.savefig("Plots/2014 Ohio Crime Rate vs. Median Housing Sale(inc Pop. size).png")

# %%
Crime_PropertyValue_2015df = merge_Zillow_Crime_df[["City","2014 Median Price", "Crime Rate 2014"]]
Crime_PropertyValue_2015df.head()
plt.scatter(Crime_PropertyValue_2015df["Crime Rate 2014"], Crime_PropertyValue_2015df["2014 Median Price"], color = "teal", marker="o", edgecolor="black")

plt.title("2014 Median Housing Sale vs. Violent Crime Rate")
plt.ylabel("Median Housing Sale")
plt.xlabel("Violent Crime Rate (Per 100,000)")
plt.grid(True)
plt.show()
Crime_PropertyValue_2015df.head()
# Out:
#            City  2014 Median Price  Crime Rate 2014
# 45     Columbus            1416700       558.490439
# 13    Cleveland                  0      1339.234025
# 59   Cincinnati                  0       913.424553
# 77       Toledo             675400      1091.232438
# 113       Akron                  0       690.278992

# %%
# Crime_PropertyValue_2012df = merge_Zillow_Crime_df[["City","2012 Median Price", "Crime Rate 2012"]]
# Crime_PropertyValue_2012df.head()
# plt.scatter(Crime_PropertyValue_2012df["Crime Rate 2012"], Crime_PropertyValue_2012df["2012 Median Price"], marker="o", edgecolor="black")

# plt.title("2012 Median Property Value vs. Violent Crime Rate")
# plt.ylabel("Median Rental Value")
# plt.xlabel("Violent Crime Rate")
# plt.grid(True)
# plt.show()

# %%
#Ohio Avg. Crime Rate

CrimeRate_df = merge_Zillow_Crime_df[["2017 Population","City","Crime Rate 2013", "Crime Rate 2014",
                                      "Crime Rate 2015", "Crime Rate 2016","Crime Rate 2017", 
                                     "2014 Median Price", "2015 Median Price", "2016 Median Price", "2017 Median Price"]]
CrimeRate_df = CrimeRate_df.rename(columns={"Crime Rate 2016": "2016", "Crime Rate 2015": "2015",
                                            "Crime Rate 2014": "2014",  "Crime Rate 2013": "2013",
                                           "Crime Rate 2017": "2017"})

CrimeRate_df =CrimeRate_df.fillna(0)
#CrimeRate_df= CrimeRate_df.set_index("City")
AverageOH_Crime = CrimeRate_df.mean()
AverageOH_Crime


# students_Passmath = school_data_complete.loc[school_data_complete["math_score"]>=70, ["student_name", "math_score"]]
# Number_studentsPassmath = len(students_Passmath)
# Out:
# 2017 Population      3.719752e+04
# 2013                 1.183673e+02
# 2014                 1.602959e+02
# 2015                 1.629184e+02
# 2016                 1.614641e+02
# 2017                 1.762888e+02
# 2014 Median Price    1.016763e+06
# 2015 Median Price    1.169838e+06
# 2016 Median Price    1.501491e+06
# 2017 Median Price    1.855974e+06
# dtype: float64

# %%
size_bins = [0, 100000, 200000, 300000, 40000,880000]
bins = ["Pop. 100000 and less", "Pop. 100001 - 200000", "Pop. 200001 - 300000","Pop. 300001 - 400000","Pop. 400000 and over"]
pd.cut(CrimeRate_df["2017 Population"], [0, 100000, 200000, 300000,400000,880000], labels=bins)
CrimeRate_df["City Size"] = pd.cut(CrimeRate_df["2017 Population"],[0, 100000, 200000, 300000,400000, 880000],labels=bins)
CrimeRate_dfGrouped = CrimeRate_df.groupby("City Size")
CrimeRate_dfGrouped.mean()
crimerate_bycitysize = pd.DataFrame(CrimeRate_dfGrouped[ "2014", "2015", "2016", "2017"].mean())
crimerate_bycitysize
#Scores_by_sizeGrouped = Scores_by_size.groupby("School Size")
crimerate_bycitysize.to_csv("CrimeRate_byCitySize.csv")

# %%
years = crimerate_bycitysize.keys()
population1, = plt.plot(years, crimerate_bycitysize.loc["Pop. 400000 and over",["2014","2015","2016","2017"]], 
                                                        color = "olive", linestyle =":", label = "Columbus", marker = 'o')
population2, = plt.plot(years, crimerate_bycitysize.loc["Pop. 300001 - 400000",["2014","2015","2016","2017"]], 
                                                        color = "teal", linestyle =":", label = "Pop. 301 - 400K", marker = 'o')
population3, = plt.plot(years, crimerate_bycitysize.loc["Pop. 200001 - 300000",["2014","2015","2016","2017"]], 
                                                        color = "red", linestyle =":", label = "Pop. 201 - 300K", marker = 'o')
population4 = plt.plot(years, crimerate_bycitysize.loc["Pop. 100001 - 200000",["2014","2015","2016","2017"]], 
                                                        color = "purple", linestyle =":", label = "Pop. 101 - 200K", marker = 'o')
population4 = plt.plot(years, crimerate_bycitysize.loc["Pop. 100000 and less",["2014","2015","2016","2017"]], 
                                                        color = "black", linestyle =":", label = "Pop. 100K and Less", marker = 'o')

plt.grid()
plt.title("Average Ohio Crime Rate by Population Size", fontsize=16, fontweight='bold')
plt.ylabel("Violent Crime Rate (Per 100,000)")
plt.xlabel("Year")
plt.legend(loc='best')
plt.savefig("Plots/Avg Ohio Crime Rate by Population size.png")

# %%
size_bins = [0, 100000, 200000, 300000, 40000,880000]
bins = ["Pop. 100000 and less", "Pop. 100001 - 200000", "Pop. 200001 - 300000","Pop. 300001 - 400000","Pop. 400000 and over"]
pd.cut(CrimeRate_df["2017 Population"], [0, 100000, 200000, 300000,400000,880000], labels=bins)
CrimeRate_df["City Size"] = pd.cut(CrimeRate_df["2017 Population"],[0, 100000, 200000, 300000,400000, 880000],labels=bins)
CrimeRate_dfGrouped = CrimeRate_df.groupby("City Size")
CrimeRate_dfGrouped.mean()
Housingprice_bycitysize = pd.DataFrame(CrimeRate_dfGrouped["2014 Median Price", "2015 Median Price",
                                                              "2016 Median Price","2017 Median Price" ].mean())
Housingprice_bycitysize=Housingprice_bycitysize.rename(columns={"2014 Median Price":"2014","2015 Median Price":"2015",
                                                                "2016 Median Price":"2016","2017 Median Price":"2017"})

Housingprice_bycitysize
Housingprice_bycitysize.to_csv("HousingpricebyCitySize.csv")

# %%
years = Housingprice_bycitysize.keys()
HousePrice1, = plt.plot(years, Housingprice_bycitysize.loc["Pop. 400000 and over",["2014","2015","2016","2017"]], 
                                                        color = "olive", linestyle =":", label = "Columbus", marker = 'd')
HousePrice2, = plt.plot(years, Housingprice_bycitysize.loc["Pop. 300001 - 400000",["2014","2015","2016","2017"]], 
                                                        color = "teal", linestyle =":", label = "Pop. 301 - 400K", marker = 'd')
HousePrice3, = plt.plot(years, Housingprice_bycitysize.loc["Pop. 200001 - 300000",["2014","2015","2016","2017"]], 
                                                        color = "red", linestyle =":", label = "Pop. 201 - 300K", marker = 'd')
HousePrice4 = plt.plot(years, Housingprice_bycitysize.loc["Pop. 100001 - 200000",["2014","2015","2016","2017"]], 
                                                        color = "purple", linestyle =":", label = "Pop. 101 - 200K", marker = 'd')
HousePrice5 = plt.plot(years, Housingprice_bycitysize.loc["Pop. 100000 and less",["2014","2015","2016","2017"]], 
                                                        color = "black", linestyle =":", label = "Pop. 100K and Less", marker = 'd')
plt.grid()
plt.title("Median House Price by Population Size", fontsize=16, fontweight='bold')
plt.ylabel("Median House Price")
plt.xlabel("Year")
plt.legend(loc='best')
crimeandprice_df.dtypes
plt.savefig("Plots/Avg Median Price by Population size.png")

# %%
crimeandprice_df_Pop1 = crimeandprice_df.loc[crimeandprice_df["City Size"]=="Pop. 300001 - 400000",["City Size","Year","Avg Crime Rate"]]
crimeandprice_df_Pop2 = crimeandprice_df.loc[crimeandprice_df["City Size"]=="Pop. 300001 - 400000",["City Size","Year","Avg. Median Price"]]

year = np.arange(2014, 2018, 1) 
data1 = crimeandprice_df_Pop1["Avg Crime Rate"]
data2 = crimeandprice_df_Pop2["Avg. Median Price"]
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Year')
ax1.set_ylabel('Avg. Crime Rate', color=color)
ax1.plot(year, data1, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Avg Median House Price', color=color)  # we already handled the x-label with ax1
ax2.plot(year, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.grid()
plt.title("Population Size of 301K - 400K",fontsize=16, fontweight='bold')
#fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()
crimeandprice_df_Pop1
crimeandprice_df_Pop2
# Out:
#                City Size  Year  Avg. Median Price
# 12  Pop. 300001 - 400000  2014                0.0
# 13  Pop. 300001 - 400000  2015           294300.0
# 14  Pop. 300001 - 400000  2016           486200.0
# 15  Pop. 300001 - 400000  2017           625500.0

# %%
# figsize=(10,8)
# fig, ax1 = plt.subplots(figsize=(10,8))

# years = CrimeRate_df.keys()
# OhioAvg, = plt.plot(years, AverageOH_Crime, color="black", marker="*", label="Ohio Average Crime" )

# City1, = plt.plot(years, CrimeRate_df.loc['Cleveland',["2013","2014","2015","2016","2017"]], 
#                           color="green", marker = "o", label="Cleveland")
# City2, = plt.plot(years, CrimeRate_df.loc['Columbus',["2013","2014","2015","2016","2017"]], 
#                           color="red", marker = "o",label="Columbus")
# City3 = plt.plot(years, CrimeRate_df.loc['Toledo',["2013","2014","2015","2016","2017"]], 
#                           color="blue",  marker = "o", label="Toledo")
# City4 = plt.plot(years, CrimeRate_df.loc['Akron',["2013","2014","2015","2016","2017"]], 
#                           color="purple", marker = "o",label="Akron")
# City5 = plt.plot(years, CrimeRate_df.loc['Cincinnati',["2013","2014","2015","2016","2017"]], 
#                          color="yellow", marker = "o",label="Cincinnati")
# City6 = plt.plot(years, CrimeRate_df.loc['Parma',["2013","2014","2015","2016","2017"]], 
#                          color="teal", marker = "o",label="Parma")
# City7 = plt.plot(years, CrimeRate_df.loc["Canton",["2013","2014","2015","2016","2017"]], 
#                          color="orange",  marker = "o", label="Canton")
# City8 = plt.plot(years, CrimeRate_df.loc["Lorain",["2013","2014","2015","2016","2017"]], 
#                          color="magenta", marker = "o",label="Lorain")
# City9 = plt.plot(years, CrimeRate_df.loc["West Chester",["2013","2014","2015","2016","2017"]], 
#                           color="coral", marker = "o", label= "West Chester")
# City10 = plt.plot(years, CrimeRate_df.loc["Hamilton",["2013","2014","2015","2016","2017"]], 
#                           color="olive", marker = "o",label="Hamilton")

# plt.title("Average Ohio Crime vs Top 10 City by Population")
# plt.ylabel("Violent Crime Rate")
# plt.xlabel("Year")
# plt.legend(loc='upper left')
# plt.grid(True)
# plt.show()

# %%
Percent_ChangeCrimeHouse_df = merge_Zillow_Crime_df[["City","Crime Rate 2016","Crime Rate 2017", "2017 Median Price", 
                                        "2016 Median Price"]]
Percent_ChangeCrimeHouse_df["Percent_Change_Crime"] = ((Percent_ChangeCrimeHouse_df["Crime Rate 2017"]/Percent_ChangeCrimeHouse_df["Crime Rate 2016"])-1)*100

Percent_ChangeCrimeHouse_df["Percent_Change_HousePrice"]= ((Percent_ChangeCrimeHouse_df["2017 Median Price"]/Percent_ChangeCrimeHouse_df["2016 Median Price"])-1)*100
Percent_ChangeCrimeHouse_df =Percent_ChangeCrimeHouse_df.dropna(0)
Percent_ChangeCrimeHouse_df
# Out:
# C:\Users\maria\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\maria\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#                   City  Crime Rate 2016  Crime Rate 2017  2017 Median Price  \
# 45            Columbus       521.730057       513.411411            1749600
# 13           Cleveland      1630.906177      1556.762536             625500
# 59          Cincinnati       910.064240       947.124193            1436800
# 77              Toledo      1192.315153      1020.872126             861900
# 113              Akron       616.454676       697.525986             692400
# 25               Parma       135.719312       177.716158            1243300
# 4            Fairfield       256.949311        50.096898            1696900
# 108             Canton       944.844526      1176.950909             719600
# 81          Youngstown       646.719651       699.771439             308200
# 74              Lorain       199.808058       585.814801             455400
# 5             Hamilton       512.631562       502.464006            1762600
# 8         West Chester        70.399476       104.258300            2642900
# 9          Springfield       690.721476       628.791870            1072500
# 58           Kettering       132.932714       128.015216            1524200
# 71              Elyria       300.188317       356.436383            1037400
# 20            Lakewood       125.126616       147.554386            1791500
# 115     Cuyahoga Falls       136.556335        99.704955            1446900
# 18              Euclid       579.973005       640.998519             700300
# 54         Beavercreek        68.832007        81.594091            2147700
# 17   Cleveland Heights       324.413818       294.216732            1103900
# 3            Fairfield       256.949311       211.133788            1696900
# 65             Findlay       128.778307       308.627092            1711400
# 47          Grove City       107.069047       116.276193            2036500
# 39           Lancaster       352.861683       317.293759            1568000
# 80            Boardman       136.047566       155.311131            1072100
# 32              Dublin        51.424457        68.803833            2323100
# 48            Hilliard        94.740469        47.034086            2915100
# 46             Gahanna        57.373992        70.936072            2444200
# 49     Upper Arlington        45.519203        34.077356            4276500
# 84           Brunswick        71.892793        60.279006            2103500
# ..                 ...              ...              ...                ...
# 51          New Albany        48.971596        37.488285            5888300
# 79              London        69.361871       137.227995            1535600
# 88           Tipp City        70.415451        40.172743            2041300
# 11            Loveland         0.000000       100.472219            1630000
# 111         Louisville       153.592979        21.337885            1579200
# 44        Reynoldsburg       222.028099       273.612783            1931900
# 24       Olmsted Falls        33.863867        33.715442            1944100
# 34         Westerville        52.636773       105.497597            3144600
# 2          Saint Marys        60.562016        36.518564            1209400
# 83            Canfield        13.655606        41.402153            2092800
# 123           Cortland        14.505367        14.611338            1363800
# 100       Port Clinton       218.892069       354.251012            1526200
# 38           Vermilion        34.584126        34.614053            1587100
# 110       Canal Fulton        36.436509        36.845984            1160400
# 53             Chardon       135.606354       192.344682            2563400
# 37           Vermilion        34.584126        21.724962            1587100
